# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
import time
import numpy as np

from IPython import parallel

# %% [markdown]
# First, initialize OpenCV for simple facial detection

# %%
HAAR_CASCADE_PATH = "/usr/local/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml"

import cv
storage = cv.CreateMemStorage()
cascade = cv.Load(HAAR_CASCADE_PATH)

# %% [markdown]
# Then define a few functions for extracting faces from images

# %%
def extract_faces(image, faces):
    """Returns any faces in an image in a numpy array"""
    import numpy as np
    A = np.frombuffer(image.tostring(), dtype=np.uint8).reshape((image.height, image.width, image.nChannels))
    A = A[:,:,::-1]
    face_arrays = []
    for face in faces:
        Aface = A[face[1]:face[1]+face[3],face[0]:face[0]+face[2]]
        face_arrays.append(Aface)
    return face_arrays


def detect_faces(filename):
    """Loads an image into OpenCV, and detects faces"""
    
    image = cv.LoadImage(filename)
    faces = []
    detected = cv.HaarDetectObjects(image, cascade, storage, 1.2, 2, cv.CV_HAAR_DO_CANNY_PRUNING, (100,100))
    if detected:
        for (x,y,w,h),n in detected:
            faces.append((x,y,w,h))
    if faces:
        return filename, extract_faces(image, faces)

# %% [markdown]
# These pictures are just everything from my iPhoto thumbnails directory,
# so vary from ~320x240 - 1024x768

# %%
import glob
pictures = glob.glob("/Users/minrk/Desktop/thumbs/*.jpg")
pictures = [ p for p in pictures if 'face' not in p ]
len(pictures)
# Out:
# 6759

# %% [markdown]
# Let's test the output of detect_faces

# %%
for p in pictures:
    found = detect_faces(p)
    if found:
        break

filename, faces = found
for face in faces:
    plt.figure()
    plt.imshow(face)

# %% [markdown]
# Hey, that looks like a face!

# %% [markdown]
# # Now in parallel

# %% [markdown]
# First, we connect our parallel Client

# %%
rc = parallel.Client()
dv = rc[:]
view = rc.load_balanced_view()

# %% [markdown]
# Then we initialize OpenCV on all of the engines (identical to what we did above)

# %%
# %%px
# HAAR_CASCADE_PATH = "/usr/local/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml"
#
# import cv
# storage = cv.CreateMemStorage()
# cascade = cv.Load(HAAR_CASCADE_PATH)

# %% [markdown]
# and make sure `extract_faces` is defined everywhere

# %%
dv['extract_faces'] = extract_faces

# %% [markdown]
# Now we can iterate through all of our pictures, and detect and display any faces we find

# %%
tic = time.time()
amr = view.map_async(detect_faces, pictures[:2000], ordered=False)
nfound = 0
for r in amr:
    if not r:
        continue
    filename, faces = r
    nfound += len(faces)
    print "%i faces found in %s" % (len(faces), filename)
    for face in faces:
        plt.imshow(face)
        plt.show()

toc = time.time()

print "found %i faces in %i images in %f s" % (nfound, len(amr), toc-tic)
# Out:
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0630.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0640.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0658.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0679.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_1787.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0611.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0718.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0641.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0657.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0706.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0653.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0702.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0704.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_0668.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_1937.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4199.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4201.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4203.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4298.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4579.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4582.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4623.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4624.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4625.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4770.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4773.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4771.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4803.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4799.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4800.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_4919.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_5400.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_5470.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_5471.jpg
# 1 faces found in /Users/minrk/Desktop/thumbs/DSC_5476.jpg
# found 35 faces in 2000 images in 48.890932 s
